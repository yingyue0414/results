# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("meshpoint.csv", header = None)
df = df.iloc[:, :-1]
df
# Out:
#          0          1         2         3          4         5         6     \
# 0   -9.475392 -10.368089  0.023422 -8.500817 -10.384128  0.002098 -7.484745
# 1   -9.482588 -10.357836  0.013214 -8.505362 -10.377821 -0.015221 -7.459900
# 2   -9.490468 -10.333113  0.032808 -8.499077 -10.363826  0.000735 -7.446647
# 3   -9.506686 -10.325990  0.037229 -8.514562 -10.381911  0.007795 -7.433610
# 4   -9.499642 -10.311094  0.041258 -8.510300 -10.388334  0.007042 -7.434348
# ..        ...        ...       ...       ...        ...       ...       ...
# 994 -9.424818 -10.353852 -0.392730 -7.881291 -10.095225  0.064704 -7.107409
# 995 -9.418886 -10.342611 -0.376481 -7.866059 -10.089544  0.065309 -7.110238
# 996 -9.420797 -10.332049 -0.378038 -7.861529 -10.080555  0.052222 -7.132423
# 997 -9.428950 -10.330168 -0.380654 -7.839333 -10.057177  0.036738 -7.114557
# 998 -9.416813 -10.341332 -0.388125 -7.837392 -10.054305  0.028822 -7.129924
#
#           7         8         9     ...      1565      1566       1567  \
# 0   -10.390982  0.022854 -6.530017  ...  0.034039  8.520735  10.415211
# 1   -10.395605 -0.003592 -6.534064  ...  0.058566  8.499206  10.431061
# 2   -10.360543  0.004086 -6.540191  ...  0.071782  8.506053  10.468470
# 3   -10.360490  0.014794 -6.509804  ...  0.058766  8.504701  10.456528
# 4   -10.360886  0.010679 -6.502922  ...  0.031835  8.503594  10.489981
# ..         ...       ...       ...  ...       ...       ...        ...
# 994 -10.100461 -0.174018 -7.014171  ... -0.677044  8.332716  10.470849
# 995 -10.101293 -0.171728 -7.031594  ... -0.672670  8.320911  10.445031
# 996 -10.099509 -0.186326 -7.080641  ... -0.680523  8.305323  10.442986
# 997 -10.106296 -0.184684 -7.071223  ... -0.704130  8.316501  10.461349
# 998 -10.103628 -0.166692 -7.054710  ... -0.724810  8.302810  10.476491
#
#          1568      1569       1570      1571       1572       1573      1574
# 0   -0.026704  9.510068  10.395107  0.009350  10.483763  10.404796 -0.009077
# 1   -0.040312  9.512416  10.381962  0.013664  10.502420  10.383417 -0.008200
# 2   -0.040465  9.508427  10.385950 -0.006997  10.489207  10.385356 -0.005475
# 3   -0.071641  9.519796  10.363292 -0.022580  10.509364  10.397554 -0.015430
# 4   -0.044573  9.529488  10.375808 -0.008528  10.516770  10.404658 -0.000645
# ..        ...       ...        ...       ...        ...        ...       ...
# 994  0.248550  9.566247  10.532421 -0.420197  10.302501  10.975058 -0.695622
# 995  0.250495  9.558680  10.537829 -0.396226  10.286615  10.989662 -0.719217
# 996  0.267919  9.546679  10.537681 -0.390428  10.300560  10.989971 -0.717447
# 997  0.270459  9.568371  10.544861 -0.421492  10.304388  10.985685 -0.721347
# 998  0.273043  9.568419  10.550730 -0.419399  10.299394  11.012299 -0.710270
#
# [999 rows x 1575 columns]

# %%
def to_xyz_string(df):
    xyz_string = ""
    for row in range(0,len(df)):
        
        # number of vertices per iter
        num_vertices = int(len(df.columns)/3)
        xyz_string += str(num_vertices) + "\n"
        
        # "iteration: NUM"
        xyz_string += "iteration: " + str(row) + "\n"
        
        # coordinates "__do + coordinates"
        for i in range(0, int(len(df.columns)/3)):
            xyz_string += "  do"
            
            def format_spaces_decimals(number):
                # 5 decimals, add spaces in front to make 13 char long in total
                if number > 9999:
                    number = 9999.99999
                if number < -9999:
                    number = -9999.99999
                numstr_5deci = "{:.5f}".format(number)
                return " " * (13 - len(numstr_5deci)) + numstr_5deci
            
            for j in range(0,3):
                xyz_string += format_spaces_decimals(df[i*3+j][row])
            
            xyz_string += "\n"
    
    print(f"complete:{row} out of {len(df)}")
    return xyz_string

# %%
#xyz_string = to_xyz_string(df)
#print(xyz_string)

# %%
f = open("out_trajectory.xyz", "w")
f.write(to_xyz_string(df))
f.close()
