# %%
import pandas as pd
import numpy as nump
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import trimesh as tr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f351938a1bda> in <module>
#       3 import matplotlib.pyplot as plt
#       4 from mpl_toolkits import mplot3d
# ----> 5 import trimesh as tr
#
# ModuleNotFoundError: No module named 'trimesh'

# %%
df = pd.read_csv("vertex490.csv", header = None)
df.columns = ["x","y","z"]
df
# Out:
#              x        y        z
# 0     -74.2991 -75.3567 -17.0005
# 1     -72.7899 -75.3574 -17.0006
# 2     -71.2813 -75.3572 -17.0007
# 3     -69.7729 -75.3560 -17.0007
# 4     -68.2645 -75.3532 -17.0007
# ...        ...      ...      ...
# 11812  69.7500  75.3442 -17.0000
# 11813  71.2500  75.3442 -17.0000
# 11814  72.7500  75.3442 -17.0000
# 11815  74.2500  75.3442 -17.0000
# 11816  75.7500  75.3442 -17.0000
#
# [11817 rows x 3 columns]

# %%
fig = plt.figure(figsize=(16, 8))
ax = plt.axes(projection='3d')

ax.scatter3D(df["x"], df["y"], df["z"], c = df["z"], s = 16.0);
